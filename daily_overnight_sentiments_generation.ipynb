# %%
import pandas as pd
import numpy as np

# %%
fname = 'dataset/nasdaq/overnight_sentiments.csv'

data = pd.read_csv( fname, index_col = 0)
data.head(3)
# Out:
#                              datetime stockcode   source  \
# 0  February 07, 2019, 09:11:00 PM EDT      AMZN  RTTNews
# 2  February 07, 2019, 06:55:00 PM EDT      AMZN  Reuters
# 3  February 07, 2019, 06:26:00 PM EDT      AMZN  Reuters
#
#                                             headline  \
# 0  Amazon CEO Jeff Bezos Accuses National Enquire...
# 2  Amazon's Bezos says National Enquirer owner tr...
# 3  Amazon's Bezos says National Enquirer tried to...
#
#                                              article  \
# 0  \n\n\nShutterstock photo\n\n@media screen and ...
# 2  \n\n\nReuters\n\n@media screen and (max-device...
# 3  \n\n\nReuters\n\n@media screen and (max-device...
#
#                                                 urls  \
# 0  https://www.nasdaq.com/article/amazon-ceo-jeff...
# 2  https://www.nasdaq.com/article/amazons-bezos-s...
# 3  https://www.nasdaq.com/article/amazons-bezos-s...
#
#                           dt  IsMarketOpen   TradeDate  \
# 0  2019-02-07 21:11:00-05:00         False  2019-02-08
# 2  2019-02-07 18:55:00-05:00         False  2019-02-08
# 3  2019-02-07 18:26:00-05:00         False  2019-02-08
#
#                                              summary  _relevance  _sentiment
# 0  Shutterstock photo@media screen and (Amazon CE...          11    0.717833
# 2  Jeff Bezos, chief executive of Amazon.com Inc,...           5    0.342760
# 3  Jeff Bezos, chief executive of Amazon.com Inc,...           5    0.450360

# %%
def GetAvgSentiment( l_sentiments, l_relevances, threshold = 1, method = 'simple'):
    '''
    Given a list of sentiments and corresponding relevance score, this function returns...
    1) "simple": equally weighted average sentiment score for sentiments' with relevance >= "threshold"
    2) "weighted": weighted average sentiment score
    '''
    
    if method == 'simple':
        # --- Method 1 ---
        # simple average sentiment with threhold cut off
    
        l_senti = []

        for i, s_ in enumerate(l_sentiments):
            if l_relevances[i] >= threshold:
                l_senti.append(s_)
        
        avg_score = np.mean(l_senti)
        return avg_score
    
    elif method == 'weighted':
        # --- Method 2 ---
        # weighted average senti w.r.t. relevance
        
        if sum(l_relevances) == 0:
            return np.nan
        
        weights = [rel/ sum(l_relevances) for rel in l_relevances]
        avg_score = 0

        for i, s_ in enumerate(l_sentiments):
            avg_score += s_ * weights[i]
        
        return avg_score
    else:
        print(f'Method = {method} is not available')
        return None

# %% [markdown]
# ## Generate Daily Sentiments

# %%
l_tickers = data['stockcode'].unique()
l_to_df = []

for stock in l_tickers:
    print(f'Calculating Daily Sentiments for {stock}...')
    idf = data[data['stockcode'] == stock]
    l_td = idf['TradeDate'].unique()
    
    for idate in l_td:
        inews = idf[idf['TradeDate']== idate]
        inews = inews.reset_index()
        
        ss = GetAvgSentiment(inews['_sentiment'], inews['_relevance'], threshold = 1, method = 'simple')
        l_to_df.append(
            [stock, idate, ss]
        )
# Out:
# Calculating Daily Sentiments for AMZN...
# Calculating Daily Sentiments for GOOGL...
# Calculating Daily Sentiments for FB...
# Calculating Daily Sentiments for NFLX...

# %% [markdown]
# ### Quick Look at the data

# %%
df_csv = pd.DataFrame(data = l_to_df, columns = ['stockcode','trade_date', 'sentiment_score'])
df_csv.describe()
# Out:
#        sentiment_score
# count       326.000000
# mean          0.435579
# std           0.128291
# min          -0.044480
# 25%           0.366718
# 50%           0.432567
# 75%           0.515777
# max           0.794580

# %% [markdown]
# ## Output to CSV

# %%
output_fname = 'dataset/nasdaq/daily_sentiment.csv'
df_csv.to_csv(output_fname)

# %% [markdown]
# ## Testing

# %%
test = data[
            data['stockcode'] == 'GOOGL' 
        ][ data['TradeDate'] == '2019-02-11']
test
# Out:
# /Users/JHO/.virtualenvs/VADER/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                 datetime stockcode       source  \
# 6025  February 09, 2019, 07:30:00 AM EDT     GOOGL  Motley Fool
# 6028  February 08, 2019, 06:13:00 PM EDT     GOOGL      Reuters
#
#                                                headline  \
# 6025                     How Are S&P 500 Stocks Chosen?
# 6028  EU countries agree on copyright reforms, deal ...
#
#                                                 article  \
# 6025  \n Though the   S&P 500    (SNPINDEX: ^GSPC) m...
# 6028  \n\n\nReuters\n\n@media screen and (max-device...
#
#                                                    urls  \
# 6025  https://www.nasdaq.com/article/how-are-sp-500-...
# 6028  https://www.nasdaq.com/article/eu-countries-ag...
#
#                              dt  IsMarketOpen   TradeDate  \
# 6025  2019-02-09 07:30:00-05:00         False  2019-02-11
# 6028  2019-02-08 18:13:00-05:00         False  2019-02-11
#
#                                                 summary  _relevance  \
# 6025  companies   must get the approval of the index...           0
# 6028  The European Union's effort to rewrite two-dec...           3
#
#       _sentiment
# 6025     0.32728
# 6028     0.39138

# %%
test_ = test.reset_index()
GetAvgSentiment(test_['_sentiment'],test_['_relevance'], threshold = 1 )
# Out:
# 0.43714

# %%
df_csv[df_csv['stockcode']== 'GOOGL']
# Out:
#     stockcode  trade_date  sentiment_score
# 61      GOOGL  2019-02-08         0.346187
# 62      GOOGL  2019-02-07              NaN
# 63      GOOGL  2019-02-06         0.340511
# 64      GOOGL  2019-02-05         0.432891
# 65      GOOGL  2019-02-04         0.547460
# 66      GOOGL  2019-02-01         0.421980
# 67      GOOGL  2019-01-31         0.584245
# 68      GOOGL  2019-01-30         0.445540
# 69      GOOGL  2019-01-29         0.481467
# 70      GOOGL  2019-01-28         0.465520
# 71      GOOGL  2019-01-25         0.711033
# 72      GOOGL  2019-01-24         0.763160
# 73      GOOGL  2019-01-23         0.206610
# 74      GOOGL  2019-01-22         0.406863
# 75      GOOGL  2019-01-18         0.524818
# 76      GOOGL  2019-01-17         0.250222
# 77      GOOGL  2019-01-16         0.584607
# 78      GOOGL  2019-01-15         0.659560
# 79      GOOGL  2019-01-14         0.403200
# 80      GOOGL  2019-01-11         0.479044
# 81      GOOGL  2019-01-10        -0.118733
# 82      GOOGL  2019-01-09         0.681700
# 83      GOOGL  2019-01-08         0.353780
# 84      GOOGL  2019-01-07         0.539070
# 85      GOOGL  2019-01-04         0.641513
# 86      GOOGL  2019-01-03         0.404130
# 87      GOOGL  2019-01-02         0.458075
# 88      GOOGL  2018-12-31         0.368047
# 89      GOOGL  2018-12-28              NaN
# 90      GOOGL  2018-12-27         0.334800
# ..        ...         ...              ...
# 124     GOOGL  2018-11-06              NaN
# 125     GOOGL  2018-11-05         0.483300
# 126     GOOGL  2018-11-02              NaN
# 127     GOOGL  2018-11-01         0.424947
# 128     GOOGL  2018-10-31         0.649260
# 129     GOOGL  2018-10-30              NaN
# 130     GOOGL  2018-10-29         0.536360
# 131     GOOGL  2018-10-26         0.430380
# 132     GOOGL  2018-10-25         0.717310
# 133     GOOGL  2018-10-24         0.492520
# 134     GOOGL  2018-10-23         0.366350
# 135     GOOGL  2018-10-22         0.425370
# 136     GOOGL  2018-10-19              NaN
# 137     GOOGL  2018-10-18         0.465090
# 138     GOOGL  2018-10-17              NaN
# 139     GOOGL  2018-10-16         0.397950
# 140     GOOGL  2018-10-15         0.399037
# 141     GOOGL  2018-10-12         0.485920
# 142     GOOGL  2018-10-11              NaN
# 143     GOOGL  2018-10-10         0.370093
# 144     GOOGL  2018-10-09         0.264120
# 145     GOOGL  2018-10-05              NaN
# 146     GOOGL  2018-10-04              NaN
# 147     GOOGL  2018-10-03         0.394253
# 148     GOOGL  2018-10-02              NaN
# 149     GOOGL  2018-10-01         0.452100
# 150     GOOGL  2018-09-28              NaN
# 151     GOOGL  2018-09-27         0.580260
# 152     GOOGL  2018-09-26         0.221740
# 153     GOOGL  2019-02-11         0.391380
#
# [93 rows x 3 columns]

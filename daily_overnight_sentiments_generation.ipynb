# %%
import pandas as pd
import numpy as np

# %%
fname = 'dataset/nasdaq/overnight_sentiments.csv'

data = pd.read_csv( fname, index_col = 0)
data.head(3)
# Out:
#                              datetime stockcode   source  \
# 0  February 07, 2019, 09:11:00 PM EDT      AMZN  RTTNews
# 2  February 07, 2019, 06:55:00 PM EDT      AMZN  Reuters
# 3  February 07, 2019, 06:26:00 PM EDT      AMZN  Reuters
#
#                                             headline  \
# 0  Amazon CEO Jeff Bezos Accuses National Enquire...
# 2  Amazon's Bezos says National Enquirer owner tr...
# 3  Amazon's Bezos says National Enquirer tried to...
#
#                                              article  \
# 0  \n\n\nShutterstock photo\n\n@media screen and ...
# 2  \n\n\nReuters\n\n@media screen and (max-device...
# 3  \n\n\nReuters\n\n@media screen and (max-device...
#
#                                                 urls  \
# 0  https://www.nasdaq.com/article/amazon-ceo-jeff...
# 2  https://www.nasdaq.com/article/amazons-bezos-s...
# 3  https://www.nasdaq.com/article/amazons-bezos-s...
#
#                           dt  IsMarketOpen   TradeDate  \
# 0  2019-02-07 21:11:00-05:00         False  2019-02-08
# 2  2019-02-07 18:55:00-05:00         False  2019-02-08
# 3  2019-02-07 18:26:00-05:00         False  2019-02-08
#
#                                              summary  _relevance  _sentiment
# 0  Shutterstock photo@media screen and (Amazon CE...          11    0.717833
# 2  Jeff Bezos, chief executive of Amazon.com Inc,...           5    0.342760
# 3  Jeff Bezos, chief executive of Amazon.com Inc,...           5    0.450360

# %%
def GetAvgSentiment( l_sentiments, l_relevances, threshold = 1, method = 'simple'):
    '''
    Given a list of sentiments and corresponding relevance score, this function returns...
    1) "simple": equally weighted average sentiment score for sentiments' with relevance >= "threshold"
    2) "weighted": weighted average sentiment score
    '''
    
    if method == 'simple':
        # --- Method 1 ---
        # simple average sentiment with threhold cut off
    
        l_senti = []

        for i, s_ in enumerate(l_sentiments):
            if l_relevances[i] > threshold:
                l_senti.append(s_)

        avg_score = np.mean(l_senti)
        return avg_score
    
    elif method == 'weighted':
        # --- Method 2 ---
        # weighted average senti w.r.t. relevance
        
        if sum(l_relevances) == 0:
            return np.nan
        
        weights = [rel/ sum(l_relevances) for rel in l_relevances]
        avg_score = 0

        for i, s_ in enumerate(l_sentiments):
            avg_score += s_ * weights[i]
        
        return avg_score
    else:
        print(f'Method = {method} is not available')
        return None

# %%
l_tickers = data['stockcode'].unique()
l_to_df = []

for stock in l_tickers:
    print(f'Calculating Daily Sentiments for {stock}...')
    idf = data[data['stockcode'] == stock]
    l_td = idf['TradeDate'].unique()
    
    for idate in l_td:
        inews = idf[idf['TradeDate']== idate]
        inews = inews.reset_index()
        
        ss = GetAvgSentiment(inews['_sentiment'], inews['_relevance'], threshold = 1, method = 'simple')
        l_to_df.append(
            [stock, idate, ss]
        )
# Out:
# Calculating Daily Sentiments for AMZN...
# Calculating Daily Sentiments for GOOGL...
# /Users/JHO/.virtualenvs/VADER/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/JHO/.virtualenvs/VADER/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Calculating Daily Sentiments for FB...
# Calculating Daily Sentiments for NFLX...

# %%
data[
    data['stockcode'] == 'AMZN' 
][ data['TradeDate'] == '2018-11-20']
# Out:
# /Users/JHO/.virtualenvs/VADER/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                 datetime stockcode   source  \
# 1629  November 20, 2018, 09:11:00 AM EDT      AMZN  Reuters
# 1630  November 20, 2018, 09:11:00 AM EDT      AMZN  Reuters
# 1631  November 20, 2018, 07:29:00 AM EDT      AMZN  Reuters
# 1632  November 20, 2018, 07:29:00 AM EDT      AMZN  Reuters
# 1633  November 20, 2018, 07:25:00 AM EDT      AMZN  Reuters
# 1634  November 20, 2018, 07:18:00 AM EDT      AMZN  Reuters
# 1635  November 20, 2018, 07:18:00 AM EDT      AMZN  Reuters
# 1636  November 20, 2018, 07:10:00 AM EDT      AMZN  Reuters
# 1637  November 19, 2018, 04:39:00 PM EDT      AMZN  Reuters
# 1638  November 19, 2018, 04:08:00 PM EDT      AMZN  Reuters
#
#                                                headline  \
# 1629  US STOCKS-Retail gloom, tech weakness pin down...
# 1630   Retail gloom, tech weakness pin down Wall Street
# 1631  Best Buy boosts profit forecast, cautious on h...
# 1632   Best Buy boosts profit forecast after sales beat
# 1633  Target 3rd-qtr comparable sales, earnings miss...
# 1634  US STOCKS-Futures drop as Apple-led tech slide...
# 1635       Futures drop as Apple-led tech slide deepens
# 1636  Kohl's tops same-store sales estimates, raises...
# 1637  US STOCKS-Wall St tumbles as Apple, internet s...
# 1638    Wall St tumbles as Apple, internet stocks swoon
#
#                                                 article  \
# 1629  \n\n\nShutterstock photo\n\n@media screen and ...
# 1630  \n\n\nReuters\n\n@media screen and (max-device...
# 1631  \n\n\nReuters\n\n@media screen and (max-device...
# 1632  \n\n\nReuters\n\n@media screen and (max-device...
# 1633  \n\n\nReuters\n\n@media screen and (max-device...
# 1634  \n\n\nShutterstock photo\n\n@media screen and ...
# 1635  \n\n\nReuters\n\n@media screen and (max-device...
# 1636  \n\n\nReuters\n\n@media screen and (max-device...
# 1637  \n\n\nShutterstock photo\n\n@media screen and ...
# 1638  \n\n\nReuters\n\n@media screen and (max-device...
#
#                                                    urls  \
# 1629  https://www.nasdaq.com/article/us-stocksretail...
# 1630  https://www.nasdaq.com/article/retail-gloom-te...
# 1631  https://www.nasdaq.com/article/best-buy-boosts...
# 1632  https://www.nasdaq.com/article/best-buy-boosts...
# 1633  https://www.nasdaq.com/article/target-3rdqtr-c...
# 1634  https://www.nasdaq.com/article/us-stocksfuture...
# 1635  https://www.nasdaq.com/article/futures-drop-as...
# 1636  https://www.nasdaq.com/article/kohls-tops-same...
# 1637  https://www.nasdaq.com/article/us-stockswall-s...
# 1638  https://www.nasdaq.com/article/wall-st-tumbles...
#
#                              dt  IsMarketOpen   TradeDate  \
# 1629  2018-11-20 09:11:00-05:00         False  2018-11-20
# 1630  2018-11-20 09:11:00-05:00         False  2018-11-20
# 1631  2018-11-20 07:29:00-05:00         False  2018-11-20
# 1632  2018-11-20 07:29:00-05:00         False  2018-11-20
# 1633  2018-11-20 07:25:00-05:00         False  2018-11-20
# 1634  2018-11-20 07:18:00-05:00         False  2018-11-20
# 1635  2018-11-20 07:18:00-05:00         False  2018-11-20
# 1636  2018-11-20 07:10:00-05:00         False  2018-11-20
# 1637  2018-11-19 16:39:00-05:00         False  2018-11-20
# 1638  2018-11-19 16:08:00-05:00         False  2018-11-20
#
#                                                 summary  _relevance  \
# 1629  Apple Inc'sAPPL.O 3.8 percent fall added to th...           0
# 1630  Home improvement chain Lowe's Cos Inc  fell 2....           0
# 1631  Best Buy Co Inc raised its full-year earnings ...           0
# 1632  Best Buy Co Inc raised its full-year earnings ...           0
# 1633  Target Corp  said on Tuesday that third-quarte...           0
# 1634  U.S. stock futures dropped by up to 1percent o...           0
# 1635  U.S. stock futures dropped by up to 1 percent ...           0
# 1636  especially on any results less than stellar," ...           0
# 1637  Shares of FacebookFB.O were down 5.7 percent,A...           0
# 1638  U.S. stocks dropped and the Nasdaq fell 3 perc...           0
#
#       _sentiment
# 1629    0.222220
# 1630   -0.002000
# 1631    0.806525
# 1632    0.806525
# 1633    0.429600
# 1634    0.087700
# 1635   -0.019800
# 1636    0.236250
# 1637   -0.175080
# 1638    0.508150

# %%
df_csv = pd.DataFrame(data = l_to_df, columns = ['stockcode','trade_date', 'sentiment_score'])
df_csv.describe()
# Out:
#        sentiment_score
# count       288.000000
# mean          0.449314
# std           0.147180
# min          -0.118733
# 25%           0.364988
# 50%           0.445180
# 75%           0.529565
# max           0.957900

# %%
output_fname = 'dataset/nasdaq/daily_sentiment.csv'
df_csv.to_csv(output_fname)

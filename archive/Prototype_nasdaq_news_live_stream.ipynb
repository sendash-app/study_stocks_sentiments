# %%
import sqlite3
import pandas as pd
import dateutil.parser
from datetime import datetime
from time import sleep
from random import randint
from bs4 import BeautifulSoup
import requests
from torrequest import TorRequest
from stem import Signal
from stem.control import Controller
import sys

# %%
# connect to the news.db, if not exist create one
conn = sqlite3.connect('news.db')
c = conn.cursor()

# %%
symbol_list = ['amzn', 'fb', 'goog', 'nflx']

# %%
# transform the csv to dataframe
df_amzn = pd.read_csv('./dataset/nasdaq/AMZN_nasdaq_news_merged.csv', index_col=0, header=0)
df_fb = pd.read_csv('./dataset/nasdaq/FB_nasdaq_news_merged.csv', index_col=0, header=0)
df_goog = pd.read_csv('./dataset/nasdaq/GOOG_nasdaq_news_cleaned.csv', index_col=0, header=0)
df_nflx = pd.read_csv('./dataset/nasdaq/NFLX_nasdaq_news_merged.csv', index_col=0, header=0)

# %%
# create a new column "unix_timestamp" for the dataframe
df_amzn["unix_timestamp"] = df_amzn["datePublished"].apply(lambda x: dateutil.parser.parse(x).timestamp())
df_fb["unix_timestamp"] = df_fb["datePublished"].apply(lambda x: dateutil.parser.parse(x).timestamp())
df_goog["unix_timestamp"] = df_goog["datePublished"].apply(lambda x: dateutil.parser.parse(x).timestamp())
df_nflx["unix_timestamp"] = df_nflx["datePublished"].apply(lambda x: dateutil.parser.parse(x).timestamp())

# %%
# create a table called nasdaq_stock_news
# structure datePublisher, title, text, url, date_EST, data_UTC, unix_timestamp, symbol
try:
    c.execute("CREATE TABLE `nasdaq_stock_news` (`datePublished` TEXT, `title` TEXT, `text` TEXT, `url` TEXT, `date_EST` TEXT, `date_UTC` TEXT, `unix_timestamp` REAL,`symbol` TEXT)")
except:
    print("Error")
# Out:
# Error

# %%
# commit the create table action
conn.commit()

# %%
# reset the index and reassign the index, coz if the index is not sequence, will return an error during insert
df_amzn = df_amzn.reset_index()
df_fb = df_fb.reset_index()
df_goog = df_goog.reset_index()
df_nflx = df_nflx.reset_index()
df_amzn = df_amzn.drop(labels="index", axis=1)
df_fb = df_fb.drop(labels="index", axis=1)
df_goog = df_goog.drop(labels="index", axis=1)
df_nflx = df_nflx.drop(labels="index", axis=1)

# %%
def insert_data_to_sqlite(df, symbol, length):
    
    """
        A function that insert data into the database
    """
    
    for i in range(length):
        c.execute("INSERT INTO nasdaq_stock_news (datePublished, title, text, url, date_EST, date_UTC, unix_timestamp, symbol) VALUES (?, ?, ?, ?, ?, ?, ?, ?)", (df['datePublished'][i], df['title'][i], df['text'][i], df['url'][i], df['date_EST'][i], df['date_UTC'][i], df['unix_timestamp'][i], symbol))
        conn.commit()

# %%
# 4 dataframe call insert_data_to_sqlite function to insert data
insert_data_to_sqlite(df_amzn, symbol_list[0], df_amzn.shape[0])
insert_data_to_sqlite(df_fb, symbol_list[1], df_fb.shape[0])
insert_data_to_sqlite(df_goog, symbol_list[2], df_goog.shape[0])
insert_data_to_sqlite(df_nflx, symbol_list[3], df_nflx.shape[0])

# %%
def check_latest_news(symbol):
    
    """
        return a latest record for finding that symbol lastest news
    """
    
    d = {}
    df_result = pd.read_sql_query("select * from nasdaq_stock_news where symbol = '" + str(symbol) + "'order by datePublished desc limit 1;", conn)
    d['symbol'] = symbol
    d['datePublished'] = df_result['datePublished'].values[0]
    d['title'] = df_result['title'].values[0]
    d['date_UTC'] = df_result['date_UTC'].values[0]
    return d

# %%
c = check_latest_news('fb')

# %%
print(c['title'])
print(c['symbol'])
print(c['datePublished'])
print(c['date_UTC'])
# Out:
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# 2019-01-28T10:52:24-05:00
# 2019-01-28 15:52:24

# %%
def get_connection(links_site):
    
    """
        to get a connection with tor request and try to scrape page
    """
    
    headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}

    with Controller.from_port(port = 9051) as controller:
        controller.authenticate(password='16:6A38BF1B14C1F2A660DF93C6DDD45B90B340D7DFF4BBB5AE03FB1F3DE4')
        print("Success!")
        controller.signal(Signal.NEWNYM)
        print("New Tor connection processed")
        tr=TorRequest(password='WTKv36s')
        tr.reset_identity() #Reset Tor
        response= tr.get('http://ipecho.net/plain')
        print("New Ip Address",response.text)
        
        for i in range(10):
            try:
                resp = tr.get(links_site, headers=headers, timeout=5)
                return resp
            except requests.exceptions.Timeout:
                print("Reconnect" + str(i+1))
                with Controller.from_port(port = 9051) as controller:
                    controller.authenticate(password='16:6A38BF1B14C1F2A660DF93C6DDD45B90B340D7DFF4BBB5AE03FB1F3DE4')
                    print("Success!")
                    controller.signal(Signal.NEWNYM)
                    print("New Tor connection processed")
                    tr=TorRequest(password='WTKv36s')
                    tr.reset_identity() #Reset Tor
                    response= tr.get('http://ipecho.net/plain')
                    print("New Ip Address",response.text)
                pass

        return resp

# %%
'''Generalized function to get all news-related articles from a Nasdaq webpage'''
def get_news_urls(links_site):
    '''scrape the html of the site'''

    print(links_site)
    
    re = get_connection(links_site)
        
    html = re.content

    '''convert html to BeautifulSoup object'''
    soup = BeautifulSoup(html , 'lxml')


    '''get list of all links on webpage'''
    #links = soup.find_all('a')
    links = soup.find_all(target="_self")


    titles = [title.getText() for title in links]
    titles = titles[1:]

    urls = [link.get('href') for link in links]
    urls = [url for url in urls if url is not None]

    '''Filter the list of urls to just the news articles'''
    news_urls = [url for url in urls if '/article/' in url]
    
    return titles, news_urls

# %%
def check_exist(db_title ,titles_list):
    
    """
        to check is the title match the list, return a boolean list(check_list) and the result.
    """
    
    check_list = []
    for i in titles_list:
        if db_title in i:
            check_list.append(True)
        else:
            check_list.append(False)

    result = [x for x in check_list if x == True]
    return result, check_list

# %%
# function test 2

landing_site = 'http://www.nasdaq.com/symbol/' + c['symbol'] + '/news-headlines'

re = get_connection(landing_site)

html = re.content

'''convert html to BeautifulSoup object'''
soup = BeautifulSoup(html , 'lxml')


'''get list of all links on webpage'''
links = soup.find_all(target="_self")

times_ = soup.find_all('small')

times_ = times_[1:]

ca = []
for i in range(len(times_)):
    ca.append(times_[i].getText())
    

for i in ca:
    c = i.strip().split(sep=" - ")[0]
    print(dateutil.parser.parse(c).strftime('%Y-%m-%d %H:%M:%S'))

titles = [title.getText() for title in links]
titles = titles[1:]

print(titles)
# Out:
# Success!
# New Tor connection processed
# New Ip Address 178.17.166.149
# 2019-02-01 00:04:00
# 2019-01-31 22:27:00
# 2019-01-31 22:03:26
# 2019-01-31 22:03:00
# 2019-01-31 21:51:00
# 2019-01-31 21:37:46
# 2019-01-31 21:37:07
# 2019-01-31 21:30:00
# 2019-01-31 21:30:00
# 2019-01-31 21:00:00
# 2018-12-04 16:25:00
# 2018-11-21 16:39:00
# 2018-11-20 12:40:00
# 2018-11-20 12:10:00
# 2018-11-20 12:01:00
# 2018-11-19 18:08:00
# ['Buy Facebook (FB) Stock After Q4 Earnings On Instagram, Mobile Ad Strength?', 'Nikkei rises to highest since mid-Dec, but Nomura, Nintendo drag', 'Stock Market Today: Facebook Grows Users, Tesla Earns a Profit', 'Sensex, Nifty Seen Higher At Open; Brace For Volatility', "Singapore's Grab tempts headquarters curse", 'Nasdaq Closes Out Best Month Since 2011', 'Close Update: Stocks Extend Fed-Fueled Rally, End January With Sizable Gains', 'Asian shares off 4-month high as China data disappoints', 'Thai Stock Market May Spin Its Wheels On Friday', 'Indonesia Stock Market Has Flat Lead For Friday']

# %%
# function test
page = 1
landing_site = 'http://www.nasdaq.com/symbol/' + c['symbol'] + '/news-headlines'

print(landing_site)

t, n = get_news_urls(landing_site)
print(n)
for i in t:
    print(i)
print(len(n))
print(len(t))
print(c['title'])
print(c['symbol'])
checking, c_list = check_exist(c['title'], t)
print(checking)
print(c_list)

while(checking == []):
    page = page + 1
    t, n = get_news_urls(landing_site + '?page=' + str(page))
    print(n)
    for i in t:
        print(i)
    print(len(n))
    print(len(t))
    print(c['title'])
    print(c['symbol'])
    checking, c_list = check_exist(c['title'], t)
    print(checking)
    print(c_list)
# Out:
# http://www.nasdaq.com/symbol/fb/news-headlines
# http://www.nasdaq.com/symbol/fb/news-headlines
# Success!
# New Tor connection processed
# New Ip Address 217.170.197.83
# ['https://www.nasdaq.com/article/buy-facebook-fb-stock-after-q4-earnings-on-instagram-mobile-ad-strength-cm1091441', 'https://www.nasdaq.com/article/stock-market-today-facebook-grows-users-tesla-earns-a-profit-cm1091305', 'https://www.nasdaq.com/article/sensex-nifty-seen-higher-at-open-brace-for-volatility-20190131-01464', 'https://www.nasdaq.com/article/singapores-grab-tempts-headquarters-curse-20190131-01467', 'https://www.nasdaq.com/article/nasdaq-closes-out-best-month-since-2011-cm1091245', 'https://www.nasdaq.com/article/close-update-stocks-extend-fed-fueled-rally-end-january-with-sizable-gains-cm1091253', 'https://www.nasdaq.com/article/asian-shares-off-4month-high-as-china-data-disappoints-20190131-01460', 'https://www.nasdaq.com/article/thai-stock-market-may-spin-its-wheels-on-friday-20190131-01457', 'https://www.nasdaq.com/article/indonesia-stock-market-has-flat-lead-for-friday-20190131-01445', 'https://www.nasdaq.com/article/apple-blocks-google-from-running-internal-ios-apps-20190131-01443']
# Buy Facebook (FB) Stock After Q4 Earnings On Instagram, Mobile Ad Strength?
# Stock Market Today: Facebook Grows Users, Tesla Earns a Profit
# Sensex, Nifty Seen Higher At Open; Brace For Volatility
# Singapore's Grab tempts headquarters curse
# Nasdaq Closes Out Best Month Since 2011
# Close Update: Stocks Extend Fed-Fueled Rally, End January With Sizable Gains
# Asian shares off 4-month high as China data disappoints
# Thai Stock Market May Spin Its Wheels On Friday
# Indonesia Stock Market Has Flat Lead For Friday
# Apple Blocks Google From Running Internal IOS Apps
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=2
# Success!
# New Tor connection processed
# New Ip Address 185.220.102.6
# ['https://www.nasdaq.com/article/5-top-stock-trades-for-friday-msft-fb-pypl-v-cm1091446', 'https://www.nasdaq.com/article/asian-shares-at-4month-high-as-hopes-rise-on-trumpxi-meet-20190131-01423', 'https://www.nasdaq.com/article/thursday-sector-leaders-utilities-technology-communications-cm1091168', 'https://www.nasdaq.com/article/hong-kong-bourse-may-test-resistance-at-28000-points-20190131-01413', 'https://www.nasdaq.com/article/mid-afternoon-market-update-cimpress-drops-after-q2-results-fortress-biotech-shares-jump-cm1091201', 'https://www.nasdaq.com/article/how-facebook-stock-will-prove-that-numbers-speak-louder-than-words-cm1091365', 'https://www.nasdaq.com/article/little-movement-expected-for-china-stock-market-20190131-01401', 'https://www.nasdaq.com/article/breaking-down-facebooks-fb-q4-earnings-margins-revenue-amp-user-growth-cm1091163', 'https://www.nasdaq.com/article/singapore-stock-market-likely-rangebound-on-friday-20190131-01388', 'https://www.nasdaq.com/article/facebook-fb-shares-cross-above-200-dma-cm1091157']
# 5 Top Stock Trades for Friday: MSFT, FB, PYPL, V
# Asian shares at 4-month high as hopes rise on Trump-Xi meet
# Thursday Sector Leaders: Utilities, Technology & Communications
# Hong Kong Bourse May Test Resistance At 28,000 Points
# Mid-Afternoon Market Update: Cimpress Drops After Q2 Results; Fortress Biotech Shares Jump
# How Facebook Stock Will Prove That Numbers Speak Louder Than Words
# Little Movement Expected For China Stock Market
# Breaking Down Facebook's (FB) Q4 Earnings, Margins, Revenue & User Growth
# Singapore Stock Market Likely Rangebound On Friday
# Facebook (FB) Shares Cross Above 200 DMA
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=3
# Success!
# New Tor connection processed
# New Ip Address 185.220.101.28
# ['https://www.nasdaq.com/article/us-appeals-court-house-panel-to-take-up-net-neutrality-20190131-01096', 'https://www.nasdaq.com/article/us-stockswall-st-ascends-sp-500-heads-for-best-month-since-2015-20190131-01049', 'https://www.nasdaq.com/article/wall-st-ascends-sp-500-heads-for-best-month-since-2015-20190131-01045', 'https://www.nasdaq.com/article/us-stocks-on-the-movege-facebook-charter-dowdupont-visa-valero-20190131-01068', 'https://www.nasdaq.com/article/sp-nasdaq-extend-rally-after-facebook-earnings-trade-talks-eyed-20190131-01013', 'https://www.nasdaq.com/article/us-stockssp-nasdaq-extend-rally-after-facebook-earnings-trade-talks-eyed-20190131-01002', 'https://www.nasdaq.com/article/more-us-companies-discussing-climate-change-in-wake-of-hurricanes-wildfires-20190131-01000', 'https://www.nasdaq.com/article/dow-joins-nasdaq-sp-500-in-positive-territory--us-commentary-20190131-00944', 'https://www.nasdaq.com/article/fed-pause-sets-stocks-for-best-january-on-record-yields-fall-20190131-00949', 'https://www.nasdaq.com/article/us-stocks-on-the-movefacebook-ge-dowdupont-ups-intel-scynexis-20190131-00923']
# U.S. appeals court, House panel to take up net neutrality
# US STOCKS-Wall St ascends, S&P 500 heads for best month since 2015
# Wall St ascends, S&P 500 heads for best month since 2015
# U.S. STOCKS ON THE MOVE-GE, Facebook, Charter, DowDuPont, Visa, Valero
# S&P, Nasdaq extend rally after Facebook earnings, trade talks eyed
# US STOCKS-S&P, Nasdaq extend rally after Facebook earnings, trade talks eyed
# More U.S. companies discussing climate change in wake of hurricanes, wildfires
# Dow Joins Nasdaq, S&P 500 In Positive Territory - U.S. Commentary
# Fed pause sets stocks for best January on record, yields fall
# U.S. STOCKS ON THE MOVE-Facebook, GE, DowDuPont, UPS, Intel, Scynexis
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=4
# Success!
# New Tor connection processed
# New Ip Address 109.70.100.22
# Reconnect1
# Success!
# New Tor connection processed
# New Ip Address 171.25.193.77
# ['https://www.nasdaq.com/article/how-did-facebook-perform-in-q4-cm1090892', 'https://www.nasdaq.com/article/nasdaq-sp-extend-rally-but-dow-posts-modest-loss--us-commentary-20190131-01227', 'https://www.nasdaq.com/article/amazon-sales-outlook-falls-short-after-record-holiday-quarter-20190131-01398', 'https://www.nasdaq.com/article/amazon-sales-outlook-disappoints-after-record-holiday-quarter-20190131-01346', 'https://www.nasdaq.com/article/amazon-firstquarter-sales-forecast-misses-estimates-shares-down-20190131-01221', 'https://www.nasdaq.com/article/news-and-earnings-combine-to-make-it-a-great-24-hours-for-stocks-cm1090826', 'https://www.nasdaq.com/article/wall-st-closes-higher-with-help-from-facebook-fed-20190131-01159', 'https://www.nasdaq.com/article/us-stocks-snapshotwall-st-closes-higher-with-help-from-facebook-fed-20190131-01129', 'https://www.nasdaq.com/article/viacom-viab-to-post-q1-earnings-disappointment-in-store-cm1090880', 'https://www.nasdaq.com/article/us-appeals-court-house-panel-to-take-up-net-neutrality-20190131-01096']
# How Did Facebook Perform In Q4?
# Nasdaq, S&P Extend Rally But Dow Posts Modest Loss - U.S. Commentary
# Amazon sales outlook falls short after record holiday quarter
# Amazon sales outlook disappoints after record holiday quarter
# Amazon first-quarter sales forecast misses estimates, shares down
# News and Earnings Combine to Make It A Great 24 Hours for Stocks
# Wall St closes higher with help from Facebook, Fed
# US STOCKS SNAPSHOT-Wall St closes higher with help from Facebook, Fed
# Viacom (VIAB) to Post Q1 Earnings: Disappointment in Store?
# U.S. appeals court, House panel to take up net neutrality
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=5
# Success!
# New Tor connection processed
# New Ip Address 51.77.201.37
# Reconnect1
# Success!
# New Tor connection processed
# New Ip Address 144.217.60.211
# Reconnect2
# Success!
# New Tor connection processed
# New Ip Address 192.160.102.168
# ['https://www.nasdaq.com/article/facebook-fb-q4-earnings-beat-estimates-ad-revenues-up-yy-cm1091025', 'https://www.nasdaq.com/article/visa-stock-is-stalling-on-earnings-but-its-not-done-yet-cm1091190', 'https://www.nasdaq.com/article/nasdaq-100-movers-pypl-chtr-cm1090756', 'https://www.nasdaq.com/article/sp-500-movers-dwdp-chtr-cm1090757', 'https://www.nasdaq.com/article/mid-morning-market-update-markets-mixed-facebook-tops-q4-expectations-cm1090827', 'https://www.nasdaq.com/article/microsoft-stock-is-still-a-buy-despite-earnings-mayhem-cm1091193', 'https://www.nasdaq.com/article/facebook-jumps-on-solid-q4-results-etfs-set-to-surge-cm1090771', 'https://www.nasdaq.com/article/us-stockswall-st-ascends-sp-500-heads-for-best-month-since-2015-20190131-01049', 'https://www.nasdaq.com/article/wall-st-ascends-sp-500-heads-for-best-month-since-2015-20190131-01045', 'https://www.nasdaq.com/article/stock-futures-return-gains-as-slowing-european-growth-weighs-nasdaq-buoyed-by-facebook-cm1090646']
# Facebook (FB) Q4 Earnings Beat Estimates, Ad Revenues Up Y/Y
# Visa Stock Is Stalling on Earnings… But It’s Not Done Yet
# Nasdaq 100 Movers: PYPL, CHTR
# S&P 500 Movers: DWDP, CHTR
# Mid-Morning Market Update: Markets Mixed; Facebook Tops Q4 Expectations
# Microsoft Stock Is Still a Buy Despite Earnings Mayhem
# Facebook Jumps on Solid Q4 Results: ETFs Set to Surge
# US STOCKS-Wall St ascends, S&P 500 heads for best month since 2015
# Wall St ascends, S&P 500 heads for best month since 2015
# Stock Futures Return Gains as Slowing European Growth Weighs; Nasdaq Buoyed By Facebook
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=6
# Success!
# New Tor connection processed
# New Ip Address 185.4.132.183
# Reconnect1
# Success!
# New Tor connection processed
# New Ip Address 144.217.90.68
# Reconnect2
# Success!
# New Tor connection processed
# New Ip Address 89.234.157.254
# Reconnect3
# Success!
# New Tor connection processed
# New Ip Address 185.220.100.252
# ['https://www.nasdaq.com/article/facebook-profit-beats-wall-st-shares-jump-after-hours-20190130-01246', 'https://www.nasdaq.com/article/facebook-quarterly-profit-revenue-beat-estimates-20190130-01157', 'https://www.nasdaq.com/article/big-thumbsup-from-wall-st-after-fed-signals-patience-on-rates-20190130-01031', 'https://www.nasdaq.com/article/us-stocksbig-thumbsup-from-wall-st-after-fed-signals-patience-on-rates-20190130-01022', 'https://www.nasdaq.com/article/big-thumbs-up-from-wall-st-after-fed-signals-patience-on-rates-20190130-00995', 'https://www.nasdaq.com/article/us-stocksbig-thumbs-up-from-wall-st-after-fed-signals-patience-on-rates-20190130-00993', 'https://www.nasdaq.com/article/wall-st-climbs-on-apple-boeing-results-fed-decision-eyed-20190130-00958', 'https://www.nasdaq.com/article/us-stockswall-st-climbs-on-apple-boeing-results-fed-decision-eyed-20190130-00943', 'https://www.nasdaq.com/article/apple-bans-facebook-from-tech-tools-for-tracking-teen-browsing-habits-20190130-00853', 'https://www.nasdaq.com/article/facebook-q4-18-earnings-conference-call-at-500-pm-et-20190130-00223']
# Facebook profit beats Wall St, shares jump after hours
# Facebook quarterly profit, revenue beat estimates
# Big thumbs-up from Wall St after Fed signals patience on rates
# US STOCKS-Big thumbs-up from Wall St after Fed signals patience on rates
# Big thumbs up from Wall St after Fed signals patience on rates
# US STOCKS-Big thumbs up from Wall St after Fed signals patience on rates
# Wall St climbs on Apple, Boeing results; Fed decision eyed
# US STOCKS-Wall St climbs on Apple, Boeing results; Fed decision eyed
# Apple bans Facebook from tech tools for tracking teen browsing habits
# Facebook Q4 18 Earnings Conference Call At 5:00 PM ET
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=7
# Success!
# New Tor connection processed
# New Ip Address 185.220.101.32
# ['https://www.nasdaq.com/article/dow-set-to-take-a-breather-after-fed-inspired-rally-cm1090486', 'https://www.nasdaq.com/article/dow-joins-nasdaq-sp-500-in-positive-territory--us-commentary-20190131-00944', 'https://www.nasdaq.com/article/fed-pause-sets-stocks-for-best-january-on-record-yields-fall-20190131-00949', 'https://www.nasdaq.com/article/us-stocks-on-the-movefacebook-ge-dowdupont-ups-intel-scynexis-20190131-00923', 'https://www.nasdaq.com/article/tech-lobby-takes-india-to-task-over-plans-to-police-online-content-20190131-00932', 'https://www.nasdaq.com/article/nasdaq-moves-sharply-higher-but-dow-posting-modest-loss--us-commentary-20190131-00868', 'https://www.nasdaq.com/article/us-stockssp-nasdaq-boosted-by-facebook-results-eyes-on-trade-talks-20190131-00870', 'https://www.nasdaq.com/article/sp-nasdaq-boosted-by-facebook-results-eyes-on-trade-talks-20190131-00864', 'https://www.nasdaq.com/article/facebook-lifts-nasdaq-sp-at-open-downbeat-earnings-weigh-on-dow-20190131-00804', 'https://www.nasdaq.com/article/us-stocks-snapshotfacebook-lifts-nasdaq-sp-at-open-downbeat-earnings-weigh-on-dow-20190131-00803']
# Dow Set to Take a Breather After Fed Inspired Rally
# Dow Joins Nasdaq, S&P 500 In Positive Territory - U.S. Commentary
# Fed pause sets stocks for best January on record, yields fall
# U.S. STOCKS ON THE MOVE-Facebook, GE, DowDuPont, UPS, Intel, Scynexis
# Tech lobby takes India to task over plans to police online content
# Nasdaq Moves Sharply Higher But Dow Posting Modest Loss - U.S. Commentary
# US STOCKS-S&P, Nasdaq boosted by Facebook results; eyes on trade talks
# S&P, Nasdaq boosted by Facebook results; eyes on trade talks
# Facebook lifts Nasdaq, S&P at open; downbeat earnings weigh on Dow
# US STOCKS SNAPSHOT-Facebook lifts Nasdaq, S&P at open; downbeat earnings weigh on Dow
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=8
# Success!
# New Tor connection processed
# New Ip Address 163.172.221.204
# Reconnect1
# Success!
# New Tor connection processed
# New Ip Address 185.220.101.66
# ['https://www.nasdaq.com/article/us-stocks-on-the-movege-tesla-facebook-dowdupont-ups-20190131-00797', 'https://www.nasdaq.com/article/us-stockssp-500-set-to-open-flat-after-fed-update-trade-worries-remain-20190131-00778', 'https://www.nasdaq.com/article/sp-500-set-to-open-flat-after-fed-update-trade-worries-remain-20190131-00771', 'https://www.nasdaq.com/article/facebook-shares-rise-as-products-back-in-focus-after-strong-q4-20190131-00667', 'https://www.nasdaq.com/article/us-stocks-on-the-movefacebook-ge-tesla-dowdupont-20190131-00606', 'https://www.nasdaq.com/article/us-stocksfutures-steady-after-fed-update-facebook-earnings-20190131-00557', 'https://www.nasdaq.com/article/futures-steady-after-fed-update-facebook-earnings-20190131-00495', 'https://www.nasdaq.com/article/facebook-user-growth-helps-dismiss-backlash-concerns-cm1090435', 'https://www.nasdaq.com/article/facebook-inc-common-stock-fb-q4-2018-earnings-conference-call-transcript-cm1090408', 'https://www.nasdaq.com/article/european-shares-set-to-rise-on-dovish-fed-20190131-00043']
# U.S. STOCKS ON THE MOVE-GE, Tesla, Facebook, DowDuPont, UPS
# US STOCKS-S&P 500 set to open flat after Fed update; trade worries remain
# S&P 500 set to open flat after Fed update; trade worries remain
# Facebook shares rise as products back in focus after strong Q4
# U.S. STOCKS ON THE MOVE-Facebook, GE, Tesla, DowDuPont
# US STOCKS-Futures steady after Fed update, Facebook earnings
# Futures steady after Fed update, Facebook earnings
# Facebook User Growth Helps Dismiss Backlash Concerns
# Facebook, Inc. Common Stock (FB) Q4 2018 Earnings Conference Call Transcript
# European Shares Set To Rise On Dovish Fed
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=9
# Success!
# New Tor connection processed
# New Ip Address 109.70.100.19
# Reconnect1
# Success!
# New Tor connection processed
# New Ip Address 185.220.101.70
# ['https://www.nasdaq.com/article/what-to-expect-from-amazons-q4-earnings-cm1090293', 'https://www.nasdaq.com/article/big-afternoon-for-q4-earnings-fb-msft-tsla-qcom-amp-v-cm1090317', 'https://www.nasdaq.com/article/facebook-fb-q4-earnings-and-revenues-beat-estimates-cm1090351', 'https://www.nasdaq.com/article/sensex-nifty-set-to-open-higher-as-fed-turns-more-dovish-20190130-01425', 'https://www.nasdaq.com/article/alibaba-revenue-slows-whats-next-for-baba-stock-amid-chinas-downturn-cm1090238', 'https://www.nasdaq.com/article/facebook-earnings-fb-stock-soars-on-q4-eps-revenue-beat-cm1090386', 'https://www.nasdaq.com/article/stocks-extend-impressive-gains-after-dovish-fed-cm1090198', 'https://www.nasdaq.com/article/facebook-surges-after-earnings-report-cm1090218', 'https://www.nasdaq.com/article/after-hours-most-active-for-jan-30-2019-czr-fb-msft-amd-mo-intc-mchi-lvs-f-bac-tak-baba-cm1090232', 'https://www.nasdaq.com/article/notable-wednesday-option-activity-fb-tsla-amzn-cm1090166']
# What To Expect From Amazon’s Q4 Earnings
# Big Afternoon for Q4 Earnings: FB, MSFT, TSLA, QCOM & V
# Facebook (FB) Q4 Earnings and Revenues Beat Estimates
# Sensex, Nifty Set To Open Higher As Fed Turns More Dovish
# Alibaba Revenue Slows: What's Next for BABA Stock Amid China's Downturn?
# Facebook Earnings: FB Stock Soars on Q4 EPS, Revenue Beat
# Stocks Extend Impressive Gains After Dovish Fed
# Facebook Surges After Earnings Report
# After Hours Most Active for Jan 30, 2019 :  CZR, FB, MSFT, AMD, MO, INTC, MCHI, LVS, F, BAC, TAK, BABA
# Notable Wednesday Option Activity: FB, TSLA, AMZN
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=10
# Success!
# New Tor connection processed
# New Ip Address 185.220.100.252
# ['https://www.nasdaq.com/article/earnings-reaction-history-facebook-inc-182-follow-through-indicator-51-sensitive-cm1090148', 'https://www.nasdaq.com/article/sony-and-facebook-are-dominating-this-next-gen-hardware-market-cm1090137', 'https://www.nasdaq.com/article/after-hours-earnings-report-for-january-30-2019-msft-fb-v-pypl-mdlz-qcom-tsla-now-ess-amp-holx-wynn-cm1090113', 'https://www.nasdaq.com/article/5-machine-learning-stocks-to-buy-for-a-smarter-portfolio-cm1090207', 'https://www.nasdaq.com/article/facebook-earnings-beat-street-shares-up-7-20190130-01167', 'https://www.nasdaq.com/article/is-facebook-stock-a-screaming-buy-ahead-of-earnings-cm1090151', 'https://www.nasdaq.com/article/facebook-inc-q4-income-rises-20190130-01159', 'https://www.nasdaq.com/article/feds-message-of-patience-extends-early-rally-on-wall-street--us-commentary-20190130-01155', 'https://www.nasdaq.com/article/facebook-keeps-attracting-digital-ads-shares-jump-after-hours-20190130-01430', 'https://www.nasdaq.com/article/facebook-profit-beats-wall-st-shares-jump-after-hours-20190130-01246']
# Earnings Reaction History: Facebook Inc., 18.2% Follow-Through Indicator, 5.1% Sensitive
# Sony and Facebook Are Dominating This Next-Gen Hardware Market
# After-Hours Earnings Report for January 30, 2019 :  MSFT, FB, V, PYPL, MDLZ, QCOM, TSLA, NOW, ESS, AMP, HOLX, WYNN
# 5 Machine-Learning Stocks to Buy for a Smarter Portfolio
# Facebook Earnings Beat Street, Shares Up 7%
# Is Facebook Stock a Screaming Buy Ahead of Earnings?
# Facebook, Inc Q4 Income Rises
# Fed's Message Of Patience Extends Early Rally On Wall Street - U.S. Commentary
# Facebook keeps attracting digital ads, shares jump after hours
# Facebook profit beats Wall St, shares jump after hours
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=11
# Success!
# New Tor connection processed
# New Ip Address 37.187.129.166
# Reconnect1
# Success!
# New Tor connection processed
# New Ip Address 81.17.27.131
# Reconnect2
# Success!
# New Tor connection processed
# New Ip Address 62.210.157.133
# ['https://www.nasdaq.com/article/facebook-quarterly-profit-revenue-beat-estimates-20190130-01157', 'https://www.nasdaq.com/article/communication-services-select-sector-spdr-fund-experiences-big-inflow-cm1089938', 'https://www.nasdaq.com/article/big-thumbsup-from-wall-st-after-fed-signals-patience-on-rates-20190130-01031', 'https://www.nasdaq.com/article/us-stocksbig-thumbsup-from-wall-st-after-fed-signals-patience-on-rates-20190130-01022', 'https://www.nasdaq.com/article/3-reasons-why-twitter-stock-will-rally-big-in-2019-cm1090122', 'https://www.nasdaq.com/article/4-consumer-stocks-that-will-defy-drop-in-sentiment-cm1089811', 'https://www.nasdaq.com/article/big-thumbs-up-from-wall-st-after-fed-signals-patience-on-rates-20190130-00995', 'https://www.nasdaq.com/article/us-stocksbig-thumbs-up-from-wall-st-after-fed-signals-patience-on-rates-20190130-00993', 'https://www.nasdaq.com/article/facebook-fb-4th-quarter-earnings-what-to-expect-cm1089575', 'https://www.nasdaq.com/article/wall-st-climbs-on-apple-boeing-results-fed-decision-eyed-20190130-00958']
# Facebook quarterly profit, revenue beat estimates
# Communication Services Select Sector SPDR Fund Experiences Big Inflow
# Big thumbs-up from Wall St after Fed signals patience on rates
# US STOCKS-Big thumbs-up from Wall St after Fed signals patience on rates
# 3 Reasons Why Twitter Stock Will Rally Big in 2019
# 4 Consumer Stocks That Will Defy Drop in Sentiment
# Big thumbs up from Wall St after Fed signals patience on rates
# US STOCKS-Big thumbs up from Wall St after Fed signals patience on rates
# Facebook (FB) 4th Quarter Earnings: What to Expect
# Wall St climbs on Apple, Boeing results; Fed decision eyed
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=12
# Success!
# New Tor connection processed
# New Ip Address 31.132.37.19
# ['https://www.nasdaq.com/article/us-stockswall-st-climbs-on-apple-boeing-results-fed-decision-eyed-20190130-00943', 'https://www.nasdaq.com/article/the-zacks-analyst-blog-highlights-check-point-software-technologies-facebook-microsoft-paypal-and-cgi-cm1089565', 'https://www.nasdaq.com/article/apple-bans-facebook-from-tech-tools-for-tracking-teen-browsing-habits-20190130-00853', 'https://www.nasdaq.com/article/bull-of-the-day-twitter-twtr-cm1089626', 'https://www.nasdaq.com/article/amazon-earnings-will-highlight-the-threat-it-poses-to-cloud-and-ad-rivals-cm1089534', 'https://www.nasdaq.com/article/facebook-q4-18-earnings-conference-call-at-500-pm-et-20190130-00223', 'https://www.nasdaq.com/article/short-seller-andrew-left-appeals-hk-market-manipulation-ruling-20190130-00017', 'https://www.nasdaq.com/article/facebook-fb-q4-earnings-preview-monthly-active-users-revenue-amp-more-cm1089445', 'https://www.nasdaq.com/article/microsoft-msft-q2-earnings-preview-revenue-intelligent-cloud-amp-more-cm1089441', 'https://www.nasdaq.com/article/earnings-watch-these-3-tech-stocks-on-wednesday-cm1089390']
# US STOCKS-Wall St climbs on Apple, Boeing results; Fed decision eyed
# The Zacks Analyst Blog Highlights: Check Point Software Technologies, Facebook, Microsoft, PayPal and CGI
# Apple bans Facebook from tech tools for tracking teen browsing habits
# Bull of the Day: Twitter (TWTR)
# Amazon Earnings Will Highlight the Threat It Poses to Cloud and Ad Rivals
# Facebook Q4 18 Earnings Conference Call At 5:00 PM ET
# Short seller Andrew Left appeals HK market manipulation ruling
# Facebook (FB) Q4 Earnings Preview: Monthly Active Users, Revenue & More
# Microsoft (MSFT) Q2 Earnings Preview: Revenue, Intelligent Cloud & More
# Earnings: Watch These 3 Tech Stocks on Wednesday
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=13
# Success!
# New Tor connection processed
# New Ip Address 199.249.230.64
# ['https://www.nasdaq.com/article/report--facebook-pays-users-to-install-app-that-harvests-their-phone-data-20190129-01357', 'https://www.nasdaq.com/article/top-storylines-to-emerge-from-busy-week-of-tech-earnings-cm1089373', 'https://www.nasdaq.com/article/facebook-typically-favors-long-trade-in-wake-of-earnings-driven-post-market-moves-cm1089288', 'https://www.nasdaq.com/article/mid-day-update-stocks-mixed-as-wall-street-digests-downbeat-earnings-shutdown-fallout-waning-consumer-confidence-cm1089216', 'https://www.nasdaq.com/article/can-facebook-challenge-microsoft-in-this-next-gen-market-cm1089251', 'https://www.nasdaq.com/article/wall-street-wavers-as-tech-gives-ground-and-industrials-rebound-20190129-01253', 'https://www.nasdaq.com/article/us-stockswall-street-wavers-as-tech-gives-ground-and-industrials-rebound-20190129-01245', 'https://www.nasdaq.com/article/pinterest-taps-goldman-sachs-jpmorgan-to-lead-ipo-20190129-01252', 'https://www.nasdaq.com/article/gold-hits-8month-high-stocks-mixed-amid-trade-caution-results-20190129-01195', 'https://www.nasdaq.com/article/us-stockswall-street-wavers-as-apple-tees-up-its-quarterly-report-20190129-01189']
# Report : Facebook Pays Users To Install App That Harvests Their Phone Data
# Top Storylines to Emerge from Busy Week of Tech Earnings
# Facebook Typically Favors Long Trade in Wake of Earnings-Driven Post-Market Moves
# Mid-Day Update: Stocks Mixed as Wall Street Digests Downbeat Earnings, Shutdown Fallout, Waning Consumer Confidence
# Can Facebook Challenge Microsoft in This Next-Gen Market?
# Wall Street wavers as tech gives ground and industrials rebound
# US STOCKS-Wall Street wavers as tech gives ground and industrials rebound
# Pinterest taps Goldman Sachs, JPMorgan to lead IPO
# Gold hits 8-month high, stocks mixed amid trade caution, results
# US STOCKS-Wall Street wavers as Apple tees up its quarterly report
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=14
# Success!
# New Tor connection processed
# New Ip Address 197.231.221.211
# ['https://www.nasdaq.com/article/wall-street-wavers-as-apple-tees-up-its-quarterly-report-20190129-01182', 'https://www.nasdaq.com/article/bolsa-euasp-500-cai-pressionado-por-setor-de-tecnologia-3m-impulsiona-dow-20190129-01135', 'https://www.nasdaq.com/article/apple-aapl-in-trouble-after-facetime-bug-reveals-user-data-cm1089063', 'https://www.nasdaq.com/article/the-zacks-analyst-blog-highlights-apple-facebook-microsoft-tesla-and-boeing-cm1089170', 'https://www.nasdaq.com/article/tech-stocks-earnings-lineup-for-jan-30-chkp-fb-amp-more-cm1088923', 'https://www.nasdaq.com/article/stock-market-news-for-jan-29-2019-cm1088931', 'https://www.nasdaq.com/article/gold-hits-eightmonth-high-stocks-mixed-amid-trade-caution-results-20190129-01000', 'https://www.nasdaq.com/article/implied-volatility-surging-for-facebook-fb-stock-options-cm1088943', 'https://www.nasdaq.com/article/will-it-get-better-for-faang-stocks-this-earnings-season-cm1088950', 'https://www.nasdaq.com/article/wall-street-mixed-as-apple-tees-up-its-quarterly-report-20190129-00975']
# Wall Street wavers as Apple tees up its quarterly report
# BOLSA EUA-S&P 500 cai pressionado por setor de tecnologia, 3M impulsiona Dow
# Apple (AAPL) in Trouble After FaceTime Bug Reveals User Data
# The Zacks Analyst Blog Highlights: Apple, Facebook, Microsoft, Tesla and Boeing
# Tech Stocks' Earnings Lineup for Jan 30: CHKP, FB & More
# Stock Market News For Jan 29, 2019
# Gold hits eight-month high, stocks mixed amid trade caution, results
# Implied Volatility Surging for Facebook (FB) Stock Options
# Will it Get Better for FAANG Stocks This Earnings Season?
# Wall Street mixed as Apple tees up its quarterly report
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=15
# Success!
# New Tor connection processed
# New Ip Address 130.149.80.199
# ['https://www.nasdaq.com/article/us-stockswall-street-mixed-as-apple-tees-up-its-quarterly-report-20190129-00974', 'https://www.nasdaq.com/article/facebooks-fb-aggressive-video-push-to-aid-q4-earnings-cm1088963', 'https://www.nasdaq.com/article/fb-is-finding-support-at-144-cm1089225', 'https://www.nasdaq.com/article/facebooks-plans-to-merge-messaging-services-raises-privacy-concerns-20190129-00948', 'https://www.nasdaq.com/article/oecd-working-on-plans-for-minimum-corporate-tax-20190129-00955', 'https://www.nasdaq.com/article/us-stockstech-keeps-nasdaq-sp-under-pressure-industrials-lift-dow-20190129-00942', 'https://www.nasdaq.com/article/tech-keeps-nasdaq-sp-under-pressure-industrials-lift-dow-20190129-00940', 'https://www.nasdaq.com/article/european-shares-hold-gains-ahead-of-events-blizzard-20190129-00888', 'https://www.nasdaq.com/article/gold-hits-sevenmonth-high-stocks-mixed-amid-trade-caution-results-20190129-00875', 'https://www.nasdaq.com/article/wall-st-edges-lower-on-tech-retreat-trade-concerns-20190129-00870']
# US STOCKS-Wall Street mixed as Apple tees up its quarterly report
# Facebook's (FB) Aggressive Video Push to Aid Q4 Earnings
# FB is Finding Support at $144
# Facebook's Plans To Merge Messaging Services Raises Privacy Concerns
# OECD working on plans for minimum corporate tax
# US STOCKS-Tech keeps Nasdaq, S&P under pressure; industrials lift Dow
# Tech keeps Nasdaq, S&P under pressure; industrials lift Dow
# European shares hold gains ahead of events blizzard
# Gold hits seven-month high, stocks mixed amid trade caution, results
# Wall St edges lower on tech retreat, trade concerns
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=16
# Success!
# New Tor connection processed
# New Ip Address 185.234.217.234
# ['https://www.nasdaq.com/article/austria-says-will-tax-internet-giants-3-pct-of-ad-revenue-20190110-00593', 'https://www.nasdaq.com/article/austria-plans-3-pct-tax-on-internet-giants-profits-20190110-00448', 'https://www.nasdaq.com/article/uk-regulator-wins-case-against-cambridge-analytica-on-data-disclosure-20190109-00933', 'https://www.nasdaq.com/article/new-yorks-iconic-chrysler-building-put-up-for-sale-20190109-00786', 'https://www.nasdaq.com/article/vietnam-says-facebook-violated-controversial-cybersecurity-law-20190109-00008', 'https://www.nasdaq.com/article/facebook-ceo-plans-public-debates-about-tech-for-2019-personal-challenge-20190108-01200', 'https://www.nasdaq.com/article/us-stocksapple-facebook-propel-wall-street-to-threeweek-peak-20190108-01155', 'https://www.nasdaq.com/article/apple-facebook-propel-wall-street-to-threeweek-peak-20190108-01151', 'https://www.nasdaq.com/article/move-aside-backseat-driver-new-tech-at-ces-monitors-you-inside-car-20190108-00438', 'https://www.nasdaq.com/article/intel-working-with-facebook-on-ai-chip-coming-later-this-year-20190107-01459']
# Austria says will tax internet giants 3 pct of ad revenue
# Austria plans 3 pct tax on internet giants' profits
# UK regulator wins case against Cambridge Analytica on data disclosure
# New York's iconic Chrysler Building put up for sale
# Vietnam says Facebook violated controversial cybersecurity law
# Facebook CEO plans public debates about tech for 2019 personal challenge
# US STOCKS-Apple, Facebook propel Wall Street to three-week peak
# Apple, Facebook propel Wall Street to three-week peak
# Move aside, backseat driver! New tech at CES monitors you inside car
# Intel working with Facebook on AI chip coming later this year
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=17
# Success!
# New Tor connection processed
# New Ip Address 87.120.36.157
# ['https://www.nasdaq.com/article/politicians-cannot-block-social-media-foes-us-appeals-court-20190107-01074', 'https://www.nasdaq.com/article/politician-cannot-block-critic-on-social-media-20190107-01043', 'https://www.nasdaq.com/article/us-stockswall-st-rebounds-on-robust-jobs-report-dovish-powell-remarks-20190104-00664', 'https://www.nasdaq.com/article/wall-st-rebounds-on-robust-jobs-report-dovish-powell-remarks-20190104-00662', 'https://www.nasdaq.com/article/us-stockswall-st-roars-back-on-robust-jobs-report-dovish-powell-remarks-20190104-00582', 'https://www.nasdaq.com/article/wall-st-roars-back-on-robust-jobs-report-dovish-powell-remarks-20190104-00580', 'https://www.nasdaq.com/article/wall-st-surges-on-strong-jobs-report-dovish-powell-comments-20190104-00554', 'https://www.nasdaq.com/article/us-stockswall-st-surges-on-strong-jobs-report-dovish-powell-comments-20190104-00546', 'https://www.nasdaq.com/article/us-stockswall-street-rallies-on-jobs-report-powell-comments-20190104-00497', 'https://www.nasdaq.com/article/wall-street-rallies-on-jobs-report-powell-comments-20190104-00494']
# Politicians cannot block social media foes -U.S. appeals court
# Politician cannot block critic on social media
# US STOCKS-Wall St rebounds on robust jobs report, dovish Powell remarks
# Wall St rebounds on robust jobs report, dovish Powell remarks
# US STOCKS-Wall St roars back on robust jobs report, dovish Powell remarks
# Wall St roars back on robust jobs report, dovish Powell remarks
# Wall St surges on strong jobs report, dovish Powell comments
# US STOCKS-Wall St surges on strong jobs report, dovish Powell comments
# US STOCKS-Wall Street rallies on jobs report, Powell comments
# Wall Street rallies on jobs report, Powell comments
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=18
# Success!
# New Tor connection processed
# New Ip Address 185.220.101.32
# ['https://www.nasdaq.com/article/a-graying-facebook-will-require-a-different-leader-20190104-00421', 'https://www.nasdaq.com/article/chinese-phone-maker-huawei-punishes-employees-for-iphone-tweet-blunder-20190104-00003', 'https://www.nasdaq.com/article/airbnb-will-succeed-where-us-peers-failed-china-20190103-01072', 'https://www.nasdaq.com/article/google-wins-us-approval-for-new-radarbased-motion-sensor-20190102-00668', 'https://www.nasdaq.com/article/us-stockswall-st-erases-losses-as-bank-energy-stocks-lead-pullback-20190102-00609', 'https://www.nasdaq.com/article/wall-st-erases-losses-as-bank-energy-stocks-lead-pullback-20190102-00605', 'https://www.nasdaq.com/article/san-bernardino-shooting-lawsuits-vs-facebook-google-twitter-dismissed-20190102-00518', 'https://www.nasdaq.com/article/wall-st-set-open-new-year-with-a-tumble-on-global-slowdown-jitters-20190102-00444', 'https://www.nasdaq.com/article/us-stockswall-st-set-open-new-year-with-a-tumble-on-global-slowdown-jitters-20190102-00441', 'https://www.nasdaq.com/article/us-stocksfutures-slide-at-start-of-year-on-concerns-of-global-slowdown-20190102-00309']
# A graying Facebook will require a different leader
# Chinese phone maker Huawei punishes employees for iPhone tweet blunder
# Airbnb will succeed where U.S. peers failed: China
# Google wins U.S. approval for new radar-based motion sensor
# US STOCKS-Wall St erases losses as bank, energy stocks lead pullback
# Wall St erases losses as bank, energy stocks lead pullback
# San Bernardino shooting lawsuits vs Facebook, Google, Twitter dismissed
# Wall St set open new year with a tumble on global slowdown jitters
# US STOCKS-Wall St set open new year with a tumble on global slowdown jitters
# US STOCKS-Futures slide at start of year on concerns of global slowdown
# 10
# 10
# Stock Market's Muted Reaction to End of Shutdown Shows Primacy of Earnings
# fb
# []
# [False, False, False, False, False, False, False, False, False, False]
# http://www.nasdaq.com/symbol/fb/news-headlines?page=19
# Success!
# New Tor connection processed

# %%
# to close the database connection 
c.close
# Out:
# <function Cursor.close>

# %%
# drop table command
c.execute("DROP Table nasdaq_stock_news")
